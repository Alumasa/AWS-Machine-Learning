# %% [markdown]
# Plot 3 plots together

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
data = pd.read_csv('datasets/births.csv')

# %%
data.head()
# Out:
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15547 entries, 0 to 15546
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    15547 non-null  int64
#  1   month   15547 non-null  int64
#  2   day     15067 non-null  float64
#  3   gender  15547 non-null  object
#  4   births  15547 non-null  int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 607.4+ KB

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,6), sharey=True)
ax[0].bar(data.year, data.births)
ax[1].scatter(data.month, data.day)
ax[2].plot(data.gender, data.year)
plt.suptitle('Categorical subplots')
# Out:
# Text(0.5, 0.98, 'Categorical subplots')

# %%
a = np.arange(0, 8.5, 0.5)
a
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ,
#        6.5, 7. , 7.5, 8. ])

# %%
plt.plot(a, a**2, 'b-', label='^2')
plt.plot(a, a**2.25, 'rs', label='^2.25')
plt.plot(a, a**2.5, 'g^', label='^2.5')
plt.plot(a, a**2.75, 'o', label='^2.75')
plt.plot(a, a**3, 'd', label='^3')
plt.grid()
plt.title('Plotting')
plt.legend()
plt.show()

# %%
plt.figure(4)
plt.subplot(321)
plt.plot([0,2,4,6,8,10], 'b--')
plt.subplot(322)
plt.plot([0,1,4,9,16,25], 'g^')
plt.subplot(323)
plt.plot([0,2,4,6,8,10], 'rs')
plt.subplot(324)
plt.plot([0,1,4,9,16,25], 'r--')
plt.subplot(325)
plt.plot([0,2,4,6,8,10], 'd')
plt.subplot(326)
plt.plot([0,1,4,9,16,25], 'r^');

# %%
x1 = [1, 2, 3, 4]
x2 = [1, 2, 3, 4]
y1= [1, 4, 9, 16]
y2 = [2, 4, 6, 8]
lines = plt.plot(x1, y1, x2, y2)
print(type(lines))
print(type(lines[0]))
plt.setp(lines[0], color='r', linewidth='2.0')
plt.setp(lines[1], color='g', linewidth='3.0')
plt.show()
# Out:
# <class 'list'>
# <class 'matplotlib.lines.Line2D'>

# %% [markdown]
# ### Distribution plots

# %%
rs = np.random.RandomState(14)
#univariate data
shoes_size = rs.normal(loc=8, scale=4, size=100)
shoes_size
# Out:
# array([ 1.42053564e+01,  8.31674410e+00,  8.69590611e+00,  7.71065374e+00,
#        -1.73176007e-02,  8.57871125e+00,  1.99532551e+00,  8.84443780e+00,
#         5.76717978e+00,  1.23381163e+01,  7.25484350e+00,  8.05864550e+00,
#         3.69772212e+00,  1.05690083e+01,  7.27865315e+00,  1.04812010e+01,
#         1.12438973e+01,  1.11117435e+01,  7.05004129e+00,  4.32350619e-01,
#         3.31151282e+00,  1.13448279e+01,  1.20370936e+01,  1.31723974e+01,
#         5.80267534e+00,  4.07314854e+00,  1.16586910e+01,  1.14922815e+01,
#         8.08844457e+00,  7.98342567e+00,  2.60349540e+00,  7.16712861e+00,
#         1.33061611e+01,  4.33495768e+00,  6.11994741e+00,  7.40222992e+00,
#         6.69895953e+00,  7.77106176e-01,  5.99851924e+00,  5.74087742e+00,
#         6.74228571e+00,  6.41329105e+00,  8.02373245e+00,  4.01144702e+00,
#         1.47643903e+01,  6.73423652e+00,  1.38605377e+01,  1.38544053e+01,
#         8.51564532e+00,  3.28702855e+00, -6.66036833e-01,  1.91274849e+00,
#         6.82844894e+00,  8.64195308e+00,  4.86859589e+00,  5.93039116e+00,
#         1.87862756e+01,  9.10081542e+00,  3.15363002e+00,  1.03489709e+01,
#         4.07265408e+00, -1.75419898e+00,  8.54446994e+00,  4.76964731e+00,
#         8.08032442e+00,  1.50394411e+01,  8.21159008e+00,  4.40075873e+00,
#         1.43537990e+01, -7.04646579e-01,  3.13113820e+00,  1.34178772e+01,
#         1.39089096e+01,  6.69511801e+00,  4.86452493e+00,  9.00372416e+00,
#         8.93428875e+00,  8.30222004e+00,  5.72852835e+00,  2.43021049e+00,
#         4.73500369e+00,  5.95449444e+00,  5.96076857e+00,  4.90615646e+00,
#         7.00593478e+00,  3.97231955e-01,  1.11992808e+01,  1.31038956e+01,
#         5.19602304e+00,  2.11539702e+00,  9.04474264e+00,  9.83403419e+00,
#         7.16193301e+00,  1.17280162e+01,  5.65210708e+00,  3.46754601e+00,
#         1.39390754e+01,  5.95734875e+00,  6.20712442e+00, -1.31965328e+00])

# %%
#bins filled automatically
sns.distplot(shoes_size, kde=False, color='b')
plt.show()

# %%
#filled kernel density estimate
sns.distplot(shoes_size, hist=False, color='g', kde_kws={'shade': True})
plt.show()

# %%
#histogram and kernel density estimate
sns.distplot(shoes_size, color='m')
plt.show()
